# %%
import numpy as np
from scipy.spatial import distance

pointA = np.array([2, 4, 6])
pointB = np.array([5, 1, 9])

euclidean_dist = distance.euclidean(pointA, pointB)
print("Euclidean Distance:", euclidean_dist)

similarity_euclidean = 1 / (1+euclidean_dist)
print("Euclidean Distance:", similarity_euclidean)
# Out:
# Euclidean Distance: 5.196152422706632
# Euclidean Distance: 0.16139047779640892

# %%
import numpy as np
from scipy.spatial import distance

pointA = np.array([3, 4, 2, 5])
pointB = np.array([1, 3, 5, 7])

euclidean_dist = distance.euclidean(pointA, pointB)
print("Euclidean Distance:", euclidean_dist)

similarity_euclidean = 1 / (1+euclidean_dist)
print("Euclidean Distance:", similarity_euclidean)
# Out:
# Euclidean Distance: 4.242640687119285
# Euclidean Distance: 0.1907435698305462

# %%
minkowski_dist_p3 =distance.minkowski(pointA, pointB, p=3)
print("minkowski Distance (p=3):", minkowski_dist_p3)
similarity_minkowsi = 1/(1+ minkowski_dist_p3)
print("Minkowsi Similarity(p=3):", similarity_minkowsi)

minkowski_dist_p2 =distance.minkowski(pointA, pointB, p=2)
print("minkowski Distance (p=2):", minkowski_dist_p2)
similarity_minkowsi = 1/(1+ minkowski_dist_p2)
print("Minkowsi Similarity(p=2):", similarity_minkowsi)

minkowski_dist_p1 =distance.minkowski(pointA, pointB, p=1)
print("minkowski Distance (p=1):", minkowski_dist_p1)
similarity_minkowsi = 1/(1+ minkowski_dist_p1)
print("Minkowsi Similarity(p=1):", similarity_minkowsi)
# Out:
# minkowski Distance (p=3): 3.530348335326063
# Minkowsi Similarity(p=3): 0.2207335785202987
# minkowski Distance (p=2): 4.242640687119285
# Minkowsi Similarity(p=2): 0.1907435698305462
# minkowski Distance (p=1): 8.0
# Minkowsi Similarity(p=1): 0.1111111111111111

# %%
import numpy as np
from scipy.spatial import distance

pointA = np.array([2,4,6])
pointB = np.array([5,1,9])

euclidean_dist=distance.euclidean(pointA, pointB)
print("Euclidean Distance:",euclidean_dist)

similarity_euclidean=1 / (1+ euclidean_dist)
print("Euclidean Similarity:",similarity_euclidean)


manhattan_dist = distance.cityblock(pointA, pointB)
print("Manhattan Distance:", manhattan_dist)
similarity_manhattan = 1 / (1 + manhattan_dist)
print("Manhattan Similarity:", similarity_manhattan)

minkowski_dist_p1 = distance.minkowski(pointA,pointB,p=1)
print("Minkowski Distance (p=1):",minkowski_dist_p1)
similarity_minkowski = 1/(1+minkowski_dist_p1)
print("Minkowski Similarity (p=1):",similarity_minkowski)

minkowski_dist_p2 = distance.minkowski(pointA,pointB,p=2)
print("Minkowski Distance (p=2):",minkowski_dist_p2)
similarity_minkowski = 1/(1+minkowski_dist_p2)
print("Minkowski Similarity (p=2):",similarity_minkowski)
# Out:
# Euclidean Distance: 5.196152422706632
# Euclidean Similarity: 0.16139047779640892
# Manhattan Distance: 9
# Manhattan Similarity: 0.1
# Minkowski Distance (p=1): 9.0
# Minkowski Similarity (p=1): 0.1
# Minkowski Distance (p=2): 5.196152422706632
# Minkowski Similarity (p=2): 0.16139047779640892

# %%
import pandas as pd
df = pd.DataFrame({
    'X': [10,20,30,40,50],
    'Y': [12,24,33,45,60] })
corr_matrix = df.corr(method='pearson')
print("Pearson Correlation Matrix:\n", corr_matrix)
# Out:
# Pearson Correlation Matrix:
#            X         Y
# X  1.000000  0.996403
# Y  0.996403  1.000000

# %%
import pandas as pd
df = pd.DataFrame({
    'DS': [10,20,30],
    'QC': [12,24,33],
    'TOC': [5,10,15]
})
corr_matrix = df.corr(method='pearson')
print("Pearson Correlation Matrix:\n", corr_matrix)
# Out:
# Pearson Correlation Matrix:
#             DS        QC       TOC
# DS   1.000000  0.996616  1.000000
# QC   0.996616  1.000000  0.996616
# TOC  1.000000  0.996616  1.000000

# %%
import pandas as pd
df = pd.read_csv("Iris (1).csv")
print(df.corr(method = 'pearson',numeric_only=float))
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
import pandas as pd
from scipy.stats  import spearmanr

df = pd.DataFrame({
    'X': [10,20,30,40,50],
    'Y': [12,24,33,45,60] })
corr_value, p_value = spearmanr(df['X'],df['Y'])
print(f"spearmanr Correlation Coefficient: {corr_value}")
print(f"p -value: {p_value}")
# Out:
# spearmanr Correlation Coefficient: 0.9999999999999999
# p -value: 1.4042654220543602e-24

# %%
import pandas as pd
from scipy.stats  import spearmanr

df = pd.DataFrame({
    'DS': [10,20,30],
    'QC': [12,24,33],
    'TOC': [5,10,15] })
corr_value, p_value = spearmanr(df['DS'],df['QC'])
print(f"spearmanr Correlation Coefficient: {corr_value}")
print(f"p -value: {p_value}")
# Out:
# spearmanr Correlation Coefficient: 1.0
# p -value: 0.0

# %%
import pandas as pd
df = pd.read_csv("Iris (1).csv")
print(df.corr(method = 'spearman',numeric_only=float))
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.734054     -0.411539       0.868498
# SepalLengthCm  0.734054       1.000000     -0.159457       0.881386
# SepalWidthCm  -0.411539      -0.159457      1.000000      -0.303421
# PetalLengthCm  0.868498       0.881386     -0.303421       1.000000
# PetalWidthCm   0.879045       0.834421     -0.277511       0.936003
#
#                PetalWidthCm
# Id                 0.879045
# SepalLengthCm      0.834421
# SepalWidthCm      -0.277511
# PetalLengthCm      0.936003
# PetalWidthCm       1.000000

# %%
def hamming_distance(str1,str2):
    if len(str1) != len(str2):
        raise ValueError("Strings must be of equal length")
    return sum(ch1 != ch2 for ch1, ch2 in zip(str1, str2))
s1 = "karolin"
s2 = "kathrin"
dist = hamming_distance(s1, s2)
print(f"Hamming Distance between '{s1}' and '{s2}': {dist}")
# Out:
# Hamming Distance between 'karolin' and 'kathrin': 3

# %%
def jaccard_index(str1,str2):
    set1 ,set2 =set(str1.split()), set(str2.split())
    intersection = set1.intersection(set2)
    union=set1.union(set2)
    return len(intersection)/len(union)
s1="data science is fun"
s2="science makes data useful"
print("Jaccard Index:", jaccard_index(s1,s2))
# Out:
# Jaccard Index: 0.3333333333333333

# %%
def lcs_length(x,y):
    m,n = len(x),len(y)
    dp = [[0] * (n+1) for _ in range(m+1)]
    for i in range(m):
        for j in range(n):
            if x[i]==y[j]:
                dp[i+1][j+1] = dp[i][j] + 1
            else:
                dp[i+1][j+1]= max(dp[i][j+1], dp[i+1][j])
    return dp[m][n]
seq1 = "ABCDEF"
seq2 = "AEBDF"
length = lcs_length(seq1,seq2)
print(f"Longest Common Subsequence length between '{seq1}' and '{seq2}': {length}")
# Out:
# Longest Common Subsequence length between 'ABCDEF' and 'AEBDF': 4

# %%
def lcs_length(x,y):
    m,n = len(x),len(y)
    dp = [[0] * (n+1) for _ in range(m+1)]
    for i in range(m):
        for j in range(n):
            if x[i]==y[j]:
                dp[i+1][j+1] = dp[i][j] + 1
            else:
                dp[i+1][j+1]= max(dp[i][j+1], dp[i+1][j])
    return dp[m][n]
seq1 = "ABCDEF"
seq2 = "ACEFB"
length = lcs_length(seq1,seq2)
print(f"Longest Common Subsequence length between '{seq1}' and '{seq2}': {length}")
# Out:
# Longest Common Subsequence length between 'ABCDEF' and 'ACEFB': 4
